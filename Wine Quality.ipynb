# %% [markdown]
# ## Wine Quality

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winequality-red.csv')

# %%
qq=df.sort_values(by='quality',ascending=True)
qq
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1478            7.1             0.875         0.05             5.7      0.082
# 832            10.4             0.440         0.42             1.5      0.145
# 899             8.3             1.020         0.02             3.4      0.084
# 1374            6.8             0.815         0.00             1.2      0.267
# 459            11.6             0.580         0.66             2.2      0.074
# ...             ...               ...          ...             ...        ...
# 495            10.7             0.350         0.53             2.6      0.070
# 1403            7.2             0.330         0.33             1.7      0.061
# 1090           10.0             0.260         0.54             1.9      0.083
# 1449            7.2             0.380         0.31             2.0      0.056
# 1549            7.4             0.360         0.30             1.8      0.074
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
uni_no=df.quality.unique()
uni_qui=df.quality.value_counts().unique()
print(uni_qui)
print(uni_no)
# Out:
# [681 638 199  53  18  10]
# [5 6 7 4 8 3]

# %%
plt.figure(figsize=(20,10))
sns.histplot(df.quality,kde=True)
plt.show()

# %% [markdown]
# ## from above the graph we can understand that from 3 to 6 is the bad  quality and 7 to 8  is good quality wine

# %%
df['quality']=[1 if x>=7 else 0 for x in df['quality']]

# %%
plt.figure(figsize=(20,10))
sns.countplot(df.quality)
plt.show()

# %%
uni_no=df.quality.unique()
uni_qui=df.quality.value_counts().unique()
print(uni_qui)
print(uni_no)
# Out:
# [1382  217]
# [0 1]

# %% [markdown]
# ## 0 for bad quality and 1 for good quality

# %%
sns.pairplot(df[['fixed acidity','volatile acidity','citric acid','residual sugar','quality']],hue='quality',data=df)
plt.show()

# %%
sns.pairplot(df[['chlorides','free sulfur dioxide','total sulfur dioxide','density','quality']],hue='quality',data=df)
plt.show()

# %%
sns.pairplot(df[['pH','sulphates','alcohol','quality']],hue='quality',data=df)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df,x='alcohol',y='quality')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df,x='alcohol',y='quality')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## for best quality wine alcohol should be above 13 for medium quality wine alcohol should be above 10.50 and below this is worest wine quality

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,precision_score
from sklearn.linear_model import LogisticRegression

# %%
x=df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']]
y=df['quality']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=3)

# %%
DTC=DecisionTreeClassifier()
KNC=KNeighborsClassifier()
SVClas=SVC()
ETC=ExtraTreeClassifier()
RFC=RandomForestClassifier()
Lr=LogisticRegression()

# %%
DTC.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
KNC.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
SVClas.fit(x_train,y_train)
# Out:
# SVC()

# %%
ETC.fit(x_train,y_train)
# Out:
# ExtraTreeClassifier()

# %%
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## acurracy score on diffrent classification model on predicted test data

# %%
y_predDTC=DTC.predict(x_test)
print("accuracy_score" ,accuracy_score(y_test,y_predDTC)*100)
print("precision_score" ,precision_score(y_test,y_predDTC)*100)
# Out:
# accuracy_score 86.875
# precision_score 50.0

# %%
y_predKNC=KNC.predict(x_test)
accuracy_score(y_test,y_predKNC)*100
print("accuracy_score" ,accuracy_score(y_test,y_predKNC)*100)
print("precision_score" ,precision_score(y_test,y_predKNC)*100)
# Out:
# accuracy_score 86.25
# precision_score 45.714285714285715

# %%
y_predSVC=SVClas.predict(x_test)
print("accuracy_score" ,accuracy_score(y_test,y_predSVC)*100)
print("precision_score" ,precision_score(y_test,y_predSVC)*100)
# Out:
# accuracy_score 86.875
# precision_score 0.0

# %%
y_predETC=ETC.predict(x_test)
print("accuracy_score" ,accuracy_score(y_test,y_predETC)*100)
print("precision_score" ,precision_score(y_test,y_predETC)*100)
# Out:
# accuracy_score 87.08333333333333
# precision_score 50.79365079365079

# %%
y_predRFC=RFC.predict(x_test)
print("accuracy_score" ,accuracy_score(y_test,y_predRFC)*100)
print("precision_score" ,precision_score(y_test,y_predRFC)*100)
# Out:
# accuracy_score 92.29166666666667
# precision_score 82.5

# %%
y_predLR=Lr.predict(x_test)
print("accuracy_score" ,accuracy_score(y_test,y_predLR)*100)
print("precision_score" ,precision_score(y_test,y_predLR)*100)
# Out:
# accuracy_score 88.125
# precision_score 58.82352941176471

# %% [markdown]
# ## We have select the Random Forest Classification with 92 percent of accuracy and and 82 percent of precision score and they wine quality is 0 and 1 which is imbalace data so precision score should be high not accuracy

# %% [markdown]
# ## now exporting model

# %%
import pickle
pickle.dump(RFC,open('model','wb'))

# %%
pp=[10.7,	0.950,	0.95	,5.5	,0.0100	,10.5	,16.0,	0.99720	,3.15,	0.65,	9.0]
cc= [10.7,	0.950,	0.95	,5.5	,0.0100	,10.5	,16.0,	0.99720	,3.15,	0.65,	15.0]

# %%
print("bad quality",RFC.predict([pp]))
print("Good quality",RFC.predict([cc]))
# Out:
# bad quality [0]
# Good quality [1]
